# %% [markdown]
# # Normal forms and relational algebra
#
# ``jeep@cphbusiness.dk``

# %% [markdown]
# # Agenda
#
# * Recap
# * Algebra
# * Relational algebra
# * Table constraints
# * Normal form BCNF, 4 and 5

# %% [markdown]
# # Learning objectives
# ## Knowledge
# The student must have knowledge of:
#
#  * Various database types and the underlying models
#  * A specific database system’s storage organisation  and query execution
#  * A specific database system’s optimisation possibilities – including advantages and disadvantages
#  * Database-specific security problems and their solutions
#  * Concepts and issues when handling big data
#  * The particular issues raised by having many simultaneous transactions, including in connection with distributed databases
#  * Relational algebra (including its relationship to execution plans)

# %% [markdown]
# ## Skills
# The student can:
#
#  * Transform logical data models into physical models in various database types
#  * Implement database optimisation
#  * Use parts of the administration tool to assist in the optimisation and tuning of existing databases, including the incorporation of a specific DBMS’ execution plans
#  * Use a specific database system’s tools for handling simultaneous transactions
#  * Use the programming and other facilities provided by a modern DBMS

# %% [markdown]
# ## Competencies
# The student can:
#
#  * Analyse the application domain in order to select a database type
#  * Divide responsibility for tasks between the application and DBMS during system development, to ensure the best possible implementation.

# %% [markdown]
# # Algebra
#
# "The study of mathematical symbols and their rules" - [Wikipedia](https://en.wikipedia.org/wiki/Algebra)

# %% [markdown]
# * Allows us to work with
#   * Symbols
#   * Variables, placeholders
#   * Abstractions

# %% [markdown]
# ## Logical *and*, *or* and *not*
#
# * Logical **and** $\land$
#   * $True \land False = False$
# * Logical **or** $\lor$
#   * $True \lor False = True$
# * Logical **not** $\neg$
#   * $\neg True = False$

# %% [markdown]
# ## Sets in algebra
#
# "Collection of distinct objects" - <a href="https://en.wikipedia.org/wiki/Set_(mathematics)">Wikipedia</a>

# %% [markdown]
# * Empty set: $Ø = \{\}$
# * Non-empty set: $\{1\}$
# * Non-empty set: $\{Red, Green\}$
# * Distinct
#   * Set of the list $[1, 2, 2, 3]$ is $\{1, 2, 3\}$
#   * Set of $[Red, Green, Yellow, Green]$ is $\{Red, Green, Yellow\}$
# * Order doesn't matter
#   * $\{Red, Green\} == \{Green, Red\}$

# %% [markdown]
# ## Different sets
#
# * The empty set, $Ø = \{\}$
# * All the students in this class
# * All the natural numbers, $\mathbb{Z} = \{0, 1, 2, 3, 4 \dots\}$
# * All the integers, $\mathbb{N} = \{-\infty, \dots, -1, 0, 1, \dots, \infty\}$
# * All the rational numbers $\mathbb{Q} = \{0, -2, 10, \frac{-2832}{123}, \frac{72}{1923892}, \frac{67821}{1298732}\}$
# * All the real numbers, $\mathbb{R} = \{0, -2, 10, \frac{-2832}{123}, \frac{72}{1923892}, \frac{67821}{1298732}, \sqrt 2, \pi, \dots\}$

# %% [markdown]
# ## Set membership
#
# * $4 \in \{1, 2, 3, 4, 5\}$
#   * 4 **is a member of** the set $\{1, 2, 3, 4, 5\}$
# * $7 \notin \{1, 2, 3, 4, 5\}$
#   * 7 **is not a member of** the set $\{1, 2, 3, 4, 5\}$

# %% [markdown]
# ## Exercise on sets
#
#
# ![Number system](images/numbersystem.png)

# %% [markdown]
# * $4 \in \mathbb{R}$
# * $\pi \in \mathbb{Q}$
# * $\frac{2}{3} \in \mathbb{R}$
# * $\sqrt 2 \notin \mathbb{Q}$
# * $-5 \in \mathbb{N}$
# * $log(7) \notin \mathbb{Q}$

# %% [markdown]
# # More symbols!
#
# * Such that: $\mid$
#   * $n \in \mathbb{Z} \mid n = 2$: N is a member of all the integers **such that** $n = 2$
# * For all: $\forall$
#   * $\forall n \in \mathbb{R}$: For all $n$ in all the real numbers
#   * $\forall n \in \mathbb{R} \mid n + n = n$
# * There exists: $\exists$
#   * $\exists n \in \mathbb{R}$: There exists a number $n$ in all the real numbers
#   * $\exists n \in \mathbb{R} \mid n * n = n$: There exists a number $n$ in all the real numbers such that $n * n = n$

# %% [markdown]
# ## Constructing sets
#
# * $\{1, 2, 4, 6, 7\}$
# * $\{1, 2, 3, \dots, 99, 100\}$
# * $\{e_0, e_1, \dots, e_{n-1}, e_{n}\}$

# %% [markdown]
# ### Set-builder notation
#
# * $\{a \in \mathbb{Z}\} $
#   * $\{-\infty, \dots, -1, 0, 1, \dots, \infty\}$
#   * The set of all a, where a is an integer
# * $\{b \in \mathbb{Z} \mid b = 10\}$
#   * $\{10\}$
#   * The set of all b, where b is a member of all the natural numbers **such that** $b = 10$
# * $\{x \mid x \in \mathbb{N}; b = -10\}$
#   * $Ø$
#   * The set of all x, where x is a member of all the natural numbers **such that** $b = -10$

# %% [markdown]
# ## Joining sets
#
# * Union
#   * $\{1, 2\} \cup \{3, 4\} = \{1, 2, 3, 4\}$
#   * $\{1, 2\} \cup \{3, 4\} = \{3, 4\} \cup \{1, 2\}$
#
# ![Union](https://upload.wikimedia.org/wikipedia/commons/thumb/3/30/Venn0111.svg/800px-Venn0111.svg.png)

# %% [markdown]
# ## Intersecting sets
#
# * Intersection
#   * $\{1, 2\} \cap \{3, 4\} = \{\}$
#   * $\{1\} \cap \{1, 2\} = \{1\}$
#
# ![Intersection](https://upload.wikimedia.org/wikipedia/commons/thumb/9/99/Venn0001.svg/800px-Venn0001.svg.png)

# %% [markdown]
# ## Subtracting sets 1/3
#
# * Complement
#   * $A \setminus B$
#
# ![Complement](https://upload.wikimedia.org/wikipedia/commons/thumb/e/e6/Venn0100.svg/800px-Venn0100.svg.png)

# %% [markdown]
# ## Subtracting sets 2/3
#
# * Complement
#   * $B \setminus A$
#
# ![Complement](https://upload.wikimedia.org/wikipedia/commons/thumb/5/5a/Venn0010.svg/800px-Venn0010.svg.png)

# %% [markdown]
# ## Subtracting sets 3/3
#
# * We now have two sets
#   * $A \setminus B$
#   * $B \setminus A$

# %% [markdown]
# * What happens when we join those two together?

# %% [markdown]
# ![Symmetric difference](https://upload.wikimedia.org/wikipedia/commons/thumb/4/46/Venn0110.svg/800px-Venn0110.svg.png)

# %% [markdown]
# ## Symmetric difference
#
# * The difference between two sets, joined together
#   * $A = \{1, 2, 3\}$ and $B = \{3, 4, 5\}$
#   * $A \setminus B = \{1, 2\}$
#   * $B \setminus A = \{4, 5\}$
#   * $(A \setminus B) \cup (B \setminus A) = A \Delta B = \{1, 2, 4, 5\}$
#
# ![Symmetric difference](https://upload.wikimedia.org/wikipedia/commons/thumb/4/46/Venn0110.svg/800px-Venn0110.svg.png)

# %% [markdown]
# ## Set operations
#
# ![Set operations](images/setops.png)

# %% [markdown]
# ## Subsets
#
# * A set can be a part of another set
#   * $\{1\} \subseteq \{1, 2, 3\}$
#   * $\{2, 3\} \subseteq \{1, 2, 3\}$
#   * $\{1, 2, 3\} \subseteq \{1, 2, 3\}$
#
# * Or it cannot
#   * $\{0\} \nsubseteq \{1, 2, 3\}$
#
# * The empty set is a subset of all sets
#   * $Ø \subseteq \{1, 2, 3\}$

# %% [markdown]
# ## Subset example
#
# ![Number system](images/numbersystem.png)
#
# * $\{\pi\} \subseteq \mathbb{R}$
# * $\{\pi\} \nsubseteq \mathbb{N}$

# %% [markdown]
# ## Cartesian product
#
# * An operator that can combine two sets into tuples of all possible combinations
#   * Written $×$
#
# * $A = \{1, 2, 3\}$
# * $B = \{Apple, Orange\}$

# %% [markdown]
# * $A × B = \{(1, Apple), (1, Orange), (2, Apple), (2, Orange), (3, Apple), (3, Orange)\}$

# %% [markdown]
# * $B × A = \{(Apple, 1), (Orange, 1), (Apple, 2), (Orange, 2), (Apple, 3), (Orange, 3)\}$

# %% [markdown]
# * $A × B = \{(a, b) \mid a \in A, b \in B\}$

# %% [markdown]
# * $R\times S =\{(r_1,r_2,\dots,r_n,s_1,s_2,\dots,s_m)|(r_1,r_2,\dots,r_n)\in R, (s_1,s_2,\dots,s_m)\in S\}$

# %% [markdown]
# ## Relational algebra
#
# * Our tables (relations) are actually sets of sets
#
# | CPR | Name | Address |
# |---------|---------|-------------|
# |140298-1234|Thomas|Copenhagen|
# |041297-5367|Nikoline|Aarhus|
# |151197-2352|Claus|Dragør|
# |050596-1142|Martin|Copenhagen|
#
# * $students = \{CPR, Name, Address\}$
#   * CPR contains all the tuples in the CPR column and so on
#
# * Written $R(CPR, Name, Address)$

# %% [markdown]
# ## Relational algebra, take 2
#
# The idea that we can use algebra (symbols and symbolic meaning) to talk about relations
#
# * Invented by Edgar Codd
# * The theoretical basis for SQL implementations
# * Incredibly useful when reasoning about and understanding your queries

# %% [markdown]
# ## Algebraic operations on relations
#
# * $\{CPR\} \cup \{Name, Address\}$
#   * $\{CPR, Name, Address\}$

# %% [markdown]
# * $\{CPR, Name\} \cap \{CPR, Address\}$
#   * $\{CPR\}$

# %% [markdown]
# * $\{CPR, Name\} \setminus \{Name, Address\}$
#   * $\{CPR\}$

# %% [markdown]
# ## Relational algebra lingo
#
# * Selections: $\sigma_{\varphi}(R)$
#   * Selects sets based on a condition
#   * ``SELECT ... FROM ... WHERE``
# * Projections: $\Pi_{a_1, a_2, \dots, a_n}(R)$
#   * Column selection in a relation
#   * ``SELECT name, address FROM ... DISTINCT``
# * Joins: $A \bowtie B$
#   * We'll get back to that

# %% [markdown]
# # Getting some data to play with
#
# ``docker run -p 5432:5432 --name data jegp/soft2018-data``
#
# * Try to log in: ``docker exec -it data bash -c "psql -U appdev"``

# %% [markdown]
# ## Running PostgreSQL in Jupyter
#
# ``docker run -p 8888:8888 --name jupyter --link data -v `pwd`:/home/jovyan -it jegp/soft2018-jupyter``
#
# * Don't forget to link the containers!
# * Click on the link in your terminal

# %% [markdown]
# ## Exporting Jupyter files to your host machine
#
# * When you start Jupyter, the notebooks will be saved in side the container
# * To export them you need to map a folder on your host machine with a folder on your running container
#   * Note: The Unix command for finding the present working directory is ``pwd``
#
#
# * To expose a volume you will have to map a folder from a host to the container, just like with ports
# * The syntax is ``-v host-folder:container-folder``
#
#
# * In our case you'll have to map your current directory to the ``/home/jovyan`` folder inside the container:
#    * ```pwd`:/home/jovyan``
#    * The full command is available in the above cell

# %% [markdown]
# ## Sql magic
#
# * In Jupyter ``%%`` means that you are evaluating something else than jupyter
#   * ``%%`` is multiline
#   * ``%`` is singleline
# * In our case we can use it to run SQL:
#
#       %sql SELECT 1;

# %% [markdown]
# ## Jupyter can now connect to your database!

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
c = %sql SELECT * FROM public.tweet LIMIT 100;
# Out:
# 100 rows affected.

# %%
type(c)
# Out:
# sql.run.ResultSet

# %%
# %sql SELECT * FROM information_schema.tables;
# Out:
# 240 rows affected.
# [('appdev', 'chinook', 'invoice', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'chinook', 'customer', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'chinook', 'mediatype', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'chinook', 'playlist', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'eav', 'support', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'chinook', 'genre', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'chinook', 'invoiceline', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_type', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'chinook', 'track', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'chinook', 'playlisttrack', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'eav', 'customer', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'eav', 'params', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'chinook', 'employee', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'chinook', 'artist', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_policy', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'f1db', 'circuits', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'eav', 'support_contract_type', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'f1db', 'constructorresults', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'f1db', 'constructors', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'f1db', 'constructorstandings', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'f1db', 'drivers', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'f1db', 'driverstandings', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'f1db', 'laptimes', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'f1db', 'pitstops', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'f1db', 'qualifying', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_settings', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'f1db', 'races', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'f1db', 'results', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'f1db', 'seasons', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'f1db', 'status', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'geoname', 'class', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'geoname', 'feature', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'geoname', 'district', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_subscription', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'geoname', 'continent', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_stat_user_tables', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'geoname', 'geoname', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_stat_xact_user_tables', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_attribute', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_proc', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_class', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_attrdef', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_constraint', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_statio_all_tables', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_statio_sys_tables', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_statio_user_tables', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_stat_all_indexes', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_inherits', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_index', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_operator', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_opfamily', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_opclass', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_am', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_amop', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_amproc', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_language', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_largeobject_metadata', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_aggregate', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_statistic_ext', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_rewrite', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_trigger', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_event_trigger', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_description', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_cast', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_enum', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_namespace', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_conversion', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_depend', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_database', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_db_role_setting', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_tablespace', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_pltemplate', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_auth_members', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_shdepend', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_shdescription', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_ts_config', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_ts_config_map', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_ts_dict', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_ts_parser', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_ts_template', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_extension', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_foreign_data_wrapper', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_foreign_server', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_foreign_table', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_replication_origin', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_default_acl', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_init_privs', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_seclabel', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_shseclabel', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_collation', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_partitioned_table', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_range', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_transform', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_sequence', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_publication', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_publication_rel', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_subscription_rel', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_roles', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_locks', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_group', 'VIEW', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_user', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_policies', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_rules', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_views', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_tables', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_matviews', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_indexes', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_sequences', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_stats', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_publication_tables', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_cursors', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_available_extensions', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_available_extension_versions', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_prepared_xacts', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_prepared_statements', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_seclabels', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_timezone_names', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_timezone_abbrevs', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_stat_all_tables', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_stat_xact_all_tables', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_stat_sys_tables', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_stat_xact_sys_tables', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_stat_sys_indexes', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_stat_user_indexes', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_statio_all_indexes', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_statio_sys_indexes', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_statio_user_indexes', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_statio_all_sequences', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_statio_sys_sequences', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_statio_user_sequences', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_stat_activity', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_stat_replication', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_stat_wal_receiver', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_stat_subscription', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_stat_ssl', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_replication_slots', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_stat_database', 'VIEW', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_stat_database_conflicts', 'VIEW', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_stat_user_functions', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_stat_xact_user_functions', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_stat_archiver', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_stat_bgwriter', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_stat_progress_vacuum', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'pg_catalog', 'pg_user_mappings', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'information_schema_catalog_name', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'attributes', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'applicable_roles', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'administrable_role_authorizations', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'check_constraint_routine_usage', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'character_sets', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'check_constraints', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'collations', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'collation_character_set_applicability', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'column_domain_usage', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'column_privileges', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'routine_privileges', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'column_udt_usage', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'columns', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'constraint_column_usage', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'role_routine_grants', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'constraint_table_usage', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'domain_constraints', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'domain_udt_usage', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'routines', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'domains', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'enabled_roles', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'key_column_usage', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'schemata', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'parameters', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'referential_constraints', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'sql_languages', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'information_schema', 'role_column_grants', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'sequences', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'sql_features', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'information_schema', 'sql_implementation_info', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'information_schema', 'sql_packages', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'information_schema', 'sql_sizing', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'information_schema', 'sql_sizing_profiles', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'information_schema', 'view_routine_usage', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'table_constraints', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'table_privileges', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'foreign_table_options', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'role_table_grants', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'view_table_usage', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'tables', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'triggered_update_columns', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'foreign_data_wrappers', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'triggers', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'views', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'udt_privileges', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'role_udt_grants', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'usage_privileges', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'data_type_privileges', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'role_usage_grants', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'user_defined_types', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'view_column_usage', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'element_types', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'column_options', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'foreign_server_options', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'foreign_data_wrapper_options', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'user_mapping_options', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'foreign_servers', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'foreign_tables', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'information_schema', 'user_mappings', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'magic', 'allsets', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'geoname', 'region', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'magic', 'cards', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'magic', 'sets', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'public', 'factbook', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'moma', 'artist', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'opendata', 'archives_planete', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'public', 'access_log', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'public', 'rate', 'BASE TABLE', None, None, 'appdev', 'public', 'rate_t', 'YES', 'YES', None),
#  ('appdev', 'public', 'commitlog', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'public', 'hashtag', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'public', 'hello', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'public', 'rates', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'public', 'tweet', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'raw', 'admin1', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'raw', 'admin2', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'raw', 'country', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'raw', 'feature', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'raw', 'geonames', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'raw', 'rates', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'sample', 'geonames', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'sandbox', 'article', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'tweet', 'activity', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'sandbox', 'lorem', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'tweet', 'membership', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'sandbox', 'category', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'sandbox', 'comment', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'tweet', 'follower', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'tweet', 'list', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'tweet', 'message_with_counters', 'VIEW', None, None, None, None, None, 'NO', 'NO', None),
#  ('appdev', 'eav', 'support_contract', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'chinook', 'album', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'geoname', 'country', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'geoname', 'neighbour', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'tweet', 'users', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None),
#  ('appdev', 'tweet', 'message', 'BASE TABLE', None, None, None, None, None, 'YES', 'NO', None)]

# %% [markdown]
# ## Guide to connect to your database
#
# * ``%load_ext sql``
# * ``%sql postgresql://appdev@data:5432/appdev``
# * ``%sql SELECT * from tweet LIMIT 10;``

# %% [markdown]
# ## Check out all the tables!
#
# * ``SELECT table_name FROM information_schema.tables;``

# %% [markdown]
# * Wait! ``information.``?!
#   * Postgresql contains ``schema``s which contains tables
#   * Hence the ``public.tweet`` $=$ ``tweet``

# %% [markdown]
# # Database normalisation
#
# Definition:
#   * "The process of restructuring a relational database in accordance with a series of so-called normal forms in order to reduce data redundancy and improve data integrity" - [Wikipedia](https://en.wikipedia.org/wiki/Database_normalization)
#
# 1. To free the collection of relations from undesirable insertion, update and deletion dependencies;
# 2. To reduce the need for restructuring the collection of relations, as new types of data are introduced, and thus increase the life span of application programs;
# 3. To make the relational model more informative to users;
# 4. To make the collection of relations neutral to the query statistics, where these statistics are liable to change as time goes by.
#
#      — E.F. Codd, "Further Normalization of the Data Base Relational Model"[3]

# %% [markdown]
# ## Database anomalies
#
# * Update anomaly
#   * If you have redundant data, and one piece of data is not properly updated (inconsistency)

# %% [markdown]
# * Insertion anomaly
#   * If you cannot assign a value to a field (``null``)

# %% [markdown]
# * Deletion anomaly
#   * If a deletion will make you delete too much

# %% [markdown]
# ## Database normalisation hierarchy
#
# ![Normalisation hierarchy](images/normalisation.png)

# %% [markdown]
# ## Normal form 1
#
# **Definition**: All fields are atomic:
#
# 1. There are no duplicated rows in the table.
# 2. Each cell is single-valued (no repeating groups or arrays).
# 3. Entries in a column (field) are of the same kind.

# %% [markdown]
# **Motivation**: Duplication makes it hard to change (update and delete anomalies)

# %% [markdown]
# ## Normal form 2
#
# **Definition**: Non-key attributes are dependent on all of the key.
#
#   1. Relation is in 1st NF
#   2. Eliminate redundant data: if an attribute depends on only part of a multi-valued key, remove it to a separate table

# %% [markdown]
# **Motivation**: Imagine you wanted to give a trick a different ID: update anomaly.

# %% [markdown]
# ## Normal form 3
#
# **Definition**: No transitive dependencies
#
# 1. Relation is in 2NF
# 2. If attributes do not contribute to a description of the key, remove them to a separate table.

# %% [markdown]
# **Motivation**: Avoids redundant data

# %% [markdown]
# ## Functional dependencies
#
# * $X \rightarrow Y$
#   * When each $X$ value is associated with precisely one $Y$ value
#
# * A functional dependency can be *trivial*
#   * When $X \subseteq Y$

# %% [markdown]
# ## Keys
#
# * One does not simply key

# %% [markdown]
# * A **superkey** is a key that *uniquely* identifies a tuple
#   * If your table contains no redundancy, the set of all attributes is a pretty trivial superkey

# %% [markdown]
# * A **minimal superkey** is the *minimal* set of attributes, required to identify a tuple
#   * This is also called a **candidate key**

# %% [markdown]
# ## Boyce-Codd normal form, or normal form 3.5
#
# **Definition**: No redundant functional dependencies
#
# 1. $X \rightarrow Y$ is a trivial functional dependency
# 2. $X$ is a *superkey*

# %% [markdown]
# **Motivation**: Less redundancy

# %% [markdown]
# ## Boyce-Codd normal form example

# %% [markdown]
# | Court | Start Time | End Time | Rate Type |
# | :--------------- |----------|-----------|---------------|---------------|
# |1|09:30|10:30|SAVER|
# |1|11:00|12:00|SAVER|
# |1|14:00|15:30|STANDARD|
# |2|10:00|11:30|PREMIUM-B|
# |2|11:30|13:30|PREMIUM-B|
# |2|15:00|16:30|PREMIUM-A|

# %% [markdown]
# * The table doesn't have any primary keys, so 2NF and 3NF is out of the question.
#   * But what's the problem?

# %% [markdown]
# * List of superkeys:
#   * {Court, Start Time}, {Court, End Time}, {Rate Type, Start Time}, {Rate Type, End Time}, {Court, Start Time, End Time}, {Rate Type, Start Time, End Time}, {Court, Rate Type, Start Time}, {Court, Rate Type, End Time}, {Court, Rate Type, Start Time, End Time} (trivial superkey)

# %% [markdown]
# * Only the first four are *candidate keys*
#   * Because e. g. $\{Court, Start Time\} \subseteq \{Court, Start Time, End Time\}$

# %% [markdown]
# ## Boyce-Codd normal form example fix
#
# | Rate Type | Court | Member Flag |
# |--------------|-----|-----
# |SAVER|1|Yes|
# |STANDARD|1|No|
# |PREMIUM-A|2|Yes|
# |PREMIUM-B|2|No|
#
# |Member Flag|Court|Start Time|End Time|
# |------|----|--------|--------|
# |Yes|1|09:30|10:30|
# |Yes|1|11:00|12:00|
# |No|1|14:00|15:30|
# |No|2|10:00|11:30|
# |No|2|11:30|13:30|
# |Yes|2|15:00|16:30|

# %% [markdown]
# ## Normal form 4
#
# * Introduced in 1977 by Ronald Fagin
# * Normally implies normal form 5
#
# * **Definition**: No multivalued dependencies
#   * For non-trivial multivalued dependencies X ↠ Y, X is a superkey

# %% [markdown]
# **Motivation**: De-duplication

# %% [markdown]
# ## Normal form 4 pizza example
#
# | Restaurant | Pizza Variety | Delivery Area
# | -------------|-------------------|--------------|
# |A1 Pizza|Thick Crust|Springfield|
# |A1 Pizza|Thick Crust|Shelbyville
# |A1 Pizza|Thick Crust|Capital City
# |A1 Pizza|Stuffed Crust|Springfield
# |A1 Pizza|Stuffed Crust|Shelbyville
# |A1 Pizza|Stuffed Crust|Capital City
# |Elite Pizza|Thin Crust|Capital City
# |Elite Pizza|Stuffed Crust|Capital City
# |Vincenzo's Pizza|Thick Crust|Springfield
# |Vincenzo's Pizza|Thick Crust|Shelbyville
# |Vincenzo's Pizza|Thin Crust|Springfield
# |Vincenzo's Pizza|Thin Crust|Shelbyville
#
# * What's the problem?

# %% [markdown]
# * Solution: Two tables with $\{Restaurant, Pizza Variety\}$ and $\{Restaurant, Delivery Area\}$

# %% [markdown]
# ## Normal form 5
#
# * Also known as project-join normal form; Ronald Fagin 1979
# * **Definition**: Every non-trivial join dependency in a table is implied by the candidate keys

# %% [markdown]
# ## Join dependency
#
# * A join dependency $\{A, B, \dots, Z\}$  is implied by the candidate key(s) if and only if each of $A$, $B$, $\dots$, $Z$ is a superkey

# %% [markdown]
# ## Normal form 5
#
# * Also known as project-join normal form
# * **Definition**: Every non-trivial join dependency in a table is implied by the candidate keys

# %% [markdown]
# **Motivation**: Avoid redundancy

# %% [markdown]
# # The Chinook dataset
#
# https://github.com/lerocha/chinook-database
#
# * Mostly based on iTunes data
#
#       SELECT * from information_schema.tables WHERE table_schema = 'chinook';
#       SELECT * from information_schema.columns WHERE table_schema = 'chinook';

# %% [markdown]
# ## Set operations on the chinook dataset
#
# * ``SELECT * FROM chinook.invoice WHERE billingcountry = 'Norway'``

# %% [markdown]
# * ``(SELECT * FROM chinook.invoice WHERE billingcountry = 'Norway') union (SELECT * FROM chinook.invoice WHERE total > 10)``
#   * Is there a smarter way to write this?

# %% [markdown]
# * ``(SELECT * FROM chinook.invoice WHERE billingcountry = 'Norway') intersect (SELECT * FROM chinook.invoice WHERE total > 10)``
#   * What is the smarter way to write this?

# %% [markdown]
# * ``(SELECT * FROM chinook.invoice WHERE billingcountry = 'Norway') except (SELECT * FROM chinook.invoice WHERE total > 10)``
#   * What is the smarter way to write this?

# %% [markdown]
# # Assignment for next week
#
# * **Deadline**: 13th of March 12:00
# * **Review deadline**: 14th of March 23:59
# * Please send a link to a GitHub repository containing your notebook
#   * Jupyter notebooks are shown directly on the GitHub webpage
#
# 1. Setup the database as described in these slides
# 2. Use the set notations (``union``, ``intersect`` or ``except``) on the Chinook dataset to find the following
#   1. The union of all the tracks with genreid 18 and 20
#     1. Write a line of text in the notebook: What did you find?
#   2. The intersection of all the invoices that are cheaper than 10 dollars and the invoices that are more expensive than 5 dollars
#     1. Write a line of text in the notebook: What did you find?
#   3. The set of all customers from USA, subtracted by the set of all customers with an email ending in 'yahoo.com'
#     1. Write a line of text in the notebook: What did you find?
#   4. The union of the set of all albums playing something by Mozart and the set of all albums playing something with Bach
#     1. Write a line of text in the notebook: What did you find?
